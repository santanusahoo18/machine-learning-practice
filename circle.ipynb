# %%
import cv2

# %%
image=cv2.imread("vk.png")

# %%
import cv2

if image is None:
    print("Image is not working.")
else:
    print("Image loaded successfully.")

    cv2.circle(image, (250, 250), 80, (0, 255, 0), -1)

    cv2.imshow("Circle", image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
# Out:
# Image loaded successfully.

# %%
import cv2

# %%
image=cv2.imread(r"C:\Users\santa\Downloads\ss.jpeg")

# %%
if image is not None:
    cv2.imshow("Santanu Sahoo", image)
    cv2.waitKey(0)          # Capital K
    cv2.destroyAllWindows()
else:
    print("Image not found.")

# %%
#  image showing

# %%
#  save the  image
ss=cv2.imwrite("santanu.jpg",image)

# %%
ss
# Out:
# True

# %%
# dimesion
h,w,c=image.shape

# %%
print(f"height:{h}\nwidth:{w}\ncolor:{c}")
# Out:
# height:1448
# width:1086
# color:3

# %%
#  gray scale conversion(convert black and white image)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
gray
# Out:
# array([[177, 177, 179, ..., 163, 163, 163],
#        [176, 177, 178, ..., 163, 163, 163],
#        [175, 175, 176, ..., 163, 163, 163],
#        ...,
#        [135, 136, 137, ..., 227, 218, 213],
#        [136, 136, 137, ..., 228, 222, 219],
#        [137, 137, 137, ..., 228, 226, 225]],
#       shape=(1448, 1086), dtype=uint8)

# %%
cv2.imshow("Santanu Sahoo", gray)
cv2.waitKey(0)          # Capital K
cv2.destroyAllWindows()

# %%
ss=cv2.imwrite("santanu(bw).jpg",gray)
